# %% [markdown]
# # Bank Markting Dataset

# %% [markdown]
# The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution.
# The goal is to predict if the client will subscribe to a term deposit.

# %%
import pandas as pd
url="C:/Users/HP/Documents/IT/CPIT-440/CPIT440 Project/bank/bank-full.csv"
bank=pd.read_csv(url, sep=';')
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# To facilitate understanding, I changed the names of the attributes

# %%
bank.columns=['age','job','marital','education','own_credit_in_default','balance','housing_loan','personal_loan','contact_communication_type','last_contact_day','last_contact_month','last_contact_duration','current_campaign_contacts',"passed_days_after_last_contact_from_previous_campaign",'total_no_contacts_before_current_campaign','outcome_of_last_campaign','term_deposit_subscribed']
bank
# Out:
#        age           job   marital  education own_credit_in_default  balance  \
# 0       58    management   married   tertiary                    no     2143
# 1       44    technician    single  secondary                    no       29
# 2       33  entrepreneur   married  secondary                    no        2
# 3       47   blue-collar   married    unknown                    no     1506
# 4       33       unknown    single    unknown                    no        1
# ...    ...           ...       ...        ...                   ...      ...
# 45206   51    technician   married   tertiary                    no      825
# 45207   71       retired  divorced    primary                    no     1729
# 45208   72       retired   married  secondary                    no     5715
# 45209   57   blue-collar   married  secondary                    no      668
# 45210   37  entrepreneur   married  secondary                    no     2971
#
# ...

# %%
bank.head()
# Out:
#    age           job  marital  education own_credit_in_default  balance  \
# 0   58    management  married   tertiary                    no     2143
# 1   44    technician   single  secondary                    no       29
# 2   33  entrepreneur  married  secondary                    no        2
# 3   47   blue-collar  married    unknown                    no     1506
# 4   33       unknown   single    unknown                    no        1
#
#   housing_loan personal_loan contact_communication_type  last_contact_day  \
# 0          yes            no                    unknown                 5
# 1          yes            no                    unknown                 5
# 2          yes           yes                    unknown                 5
# 3          yes            no                    unknown                 5
# 4           no            no                    unknown                 5
#
#   last_contact_month  last_contact_duration  current_campaign_contacts  \
# ...

# %%
bank.tail()
# Out:
#        age           job   marital  education own_credit_in_default  balance  \
# 45206   51    technician   married   tertiary                    no      825
# 45207   71       retired  divorced    primary                    no     1729
# 45208   72       retired   married  secondary                    no     5715
# 45209   57   blue-collar   married  secondary                    no      668
# 45210   37  entrepreneur   married  secondary                    no     2971
#
#       housing_loan personal_loan contact_communication_type  last_contact_day  \
# 45206           no            no                   cellular                17
# 45207           no            no                   cellular                17
# 45208           no            no                   cellular                17
# 45209           no            no                  telephone                17
# 45210           no            no                   cellular                17
#
# ...

# %% [markdown]
# ## Data Discreption

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   age                                                    45211 non-null  int64
#  1   job                                                    45211 non-null  object
#  2   marital                                                45211 non-null  object
#  3   education                                              45211 non-null  object
#  4   own_credit_in_default                                  45211 non-null  object
#  5   balance                                                45211 non-null  int64
#  6   housing_loan                                           45211 non-null  object
#  7   personal_loan                                          45211 non-null  object
# ...

# %% [markdown]
# Note : every value that is not known (missing) is filled by "unknown".
# In attribute (passed_days_after_last_contact_from_previous_campaign): -1 means client was not previously contacted

# %% [markdown]
# The attributes (age-balance-day-duration-campaign-pdays-previous) are numeric.The other attributes (job-marital-education-default-housing-loan-contact-month-poutcome-y) are string

# %% [markdown]
# The categories of string attributes :

# %%
bank["job"].value_counts()
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
bank["marital"].value_counts()
# Out:
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64

# %%
bank["education"].value_counts()
# Out:
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64

# %%
bank["own_credit_in_default"].value_counts()
# Out:
# no     44396
# yes      815
# Name: own_credit_in_default, dtype: int64

# %%
bank["housing_loan"].value_counts()
# Out:
# yes    25130
# no     20081
# Name: housing_loan, dtype: int64

# %%
bank["personal_loan"].value_counts()
# Out:
# no     37967
# yes     7244
# Name: personal_loan, dtype: int64

# %%
bank["contact_communication_type"].value_counts()
# Out:
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact_communication_type, dtype: int64

# %%
bank["last_contact_month"].value_counts()
# Out:
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: last_contact_month, dtype: int64

# %%
bank["outcome_of_last_campaign"].value_counts()
# Out:
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: outcome_of_last_campaign, dtype: int64

# %%
bank["term_deposit_subscribed"].value_counts()
# Out:
# no     39922
# yes     5289
# Name: term_deposit_subscribed, dtype: int64

# %% [markdown]
# The numeric attributes can be described by details now:

# %%
bank.describe().T
# Out:
#                                                       count         mean  \
# age                                                 45211.0    40.936210
# balance                                             45211.0  1362.272058
# last_contact_day                                    45211.0    15.806419
# last_contact_duration                               45211.0   258.163080
# current_campaign_contacts                           45211.0     2.763841
# passed_days_after_last_contact_from_previous_ca...  45211.0    40.197828
# total_no_contacts_before_current_campaign           45211.0     0.580323
#
#                                                             std     min  \
# age                                                   10.618762    18.0
# balance                                             3044.765829 -8019.0
# last_contact_day                                       8.322476     1.0
# last_contact_duration                                257.527812     0.0
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Histogram

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

bank.hist(bins=20, figsize=(20,15))

plt.suptitle('Figure 1', fontsize=30)
plt.show()

# %% [markdown]
# #### Histogram Analysis:

# %% [markdown]
# Approximately All of the histograms are right skewed which means the values are less than the mean

# %% [markdown]
# We can recognize that there are negative values in balance which may indicate that these users have a personal loan or housing loan from the bank

# %%
bank.hist(column=['balance'], bins=100, figsize=(15,7))
plt.show()

# %%
bank["housing_loan"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["personal_loan"].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# The majority of users work in blue-collar jobs

# %%
bank["job"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["marital"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["education"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["own_credit_in_default"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["contact_communication_type"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["last_contact_month"].value_counts().plot(kind='bar')
plt.show()

# %%
bank["last_contact_day"].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# The target attribute is _"term_deposit_subscribed"_ and the histogram in this figure shows 5289 users are subscribed to term deposits and 39922 are not

# %%
bank["term_deposit_subscribed"].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
from pandas.plotting import scatter_matrix
attributes = ['age','job','marital','education','own_credit_in_default','balance','housing_loan','personal_loan','contact_communication_type','last_contact_day','last_contact_month','last_contact_duration','current_campaign_contacts',"passed_days_after_last_contact_from_previous_campaign",'total_no_contacts_before_current_campaign','outcome_of_last_campaign','term_deposit_subscribed']
scatter_matrix(bank[attributes], figsize=(20, 30))
plt.show()

# %% [markdown]
# This scatter plot shows only numeric attributes (without target attributes), indicating no relationship between them.

# %%
import seaborn as sns
sns.catplot(y="job", hue="term_deposit_subscribed", kind="count",
            palette="pastel", edgecolor=".6",
            data=bank)

# %% [markdown]
# Employees in management jobs are the most likely to subscribe to term deposits, followed by those in technican.

# %%
sns.catplot(y="outcome_of_last_campaign", hue="term_deposit_subscribed", kind="count",
            palette="pastel", edgecolor=".6",
            data=bank)

# %% [markdown]
# Users who subscribed successfully to the last campaign are more likely to subscribe to the current campaign (ignoring the unknown because it is a missing value)

# %%
sns.catplot(y="contact_communication_type", hue="term_deposit_subscribed", kind="count",
            palette="pastel", edgecolor=".6",
            data=bank)

# %% [markdown]
# Celluar communication is the most common form of communication that results in subscription in term deposits

# %%
sns.catplot(data=bank, x="term_deposit_subscribed", y="last_contact_duration")

# %%
sns.catplot(data=bank, x="last_contact_duration", y="marital", hue="term_deposit_subscribed",kind="bar")

# %% [markdown]
# People who are divorcing are more likely to subscribe to term deposits, followed by married people, and then single people

# %% [markdown]
# ## Boxplot

# %%
bank.boxplot(figsize=(20,10))
plt.show()

# %% [markdown]
# In all numeric attributes, the range and IQR are small, and there are many outliers.

# %%
sns.catplot(data=bank, x="personal_loan", y="last_contact_duration", hue="term_deposit_subscribed", kind="box")

# %% [markdown]
# People who take out personal loans have longer contact durations. They also subscribe more frequently to term deposits.

# %%
sns.catplot(data=bank, x="housing_loan", y="last_contact_duration", hue="term_deposit_subscribed", kind="box")

# %% [markdown]
# Also, people who take out housing loans have longer contact durations. They also subscribe more frequently to term deposits.

# %% [markdown]
# ## Correlation

# %%
corr_matrix=bank.corr()

# %%
corr_matrix
# Out:
#                                                          age   balance  \
# age                                                 1.000000  0.097783
# balance                                             0.097783  1.000000
# last_contact_day                                   -0.009120  0.004503
# last_contact_duration                              -0.004648  0.021560
# current_campaign_contacts                           0.004760 -0.014578
# passed_days_after_last_contact_from_previous_ca... -0.023758  0.003435
# total_no_contacts_before_current_campaign           0.001288  0.016674
#
#                                                     last_contact_day  \
# age                                                        -0.009120
# balance                                                     0.004503
# last_contact_day                                            1.000000
# last_contact_duration                                      -0.030206
# ...

# %%
plt.matshow(corr_matrix)
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The correlation matrix indicates that there is no relation between the numeric attributes except _"passeddays_after_last_contact_from_previous_campaign"_ and _"totalno_contacts_before_current_campaign"_ ,there is a moderate positive relation between them.

# %% [markdown]
# As the target attribute is categorical, I used chi2 contingency method to determine if it is related to other attributes

# %% [markdown]
# * Dependent meaens they have a relation between the two attributes

# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency 

stat, p, dof, expected =chi2_contingency(pd.crosstab(bank['term_deposit_subscribed'], bank['outcome_of_last_campaign']))
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 0.0
# Dependent (reject H0)

# %% [markdown]
# **Important note from the source of the dataset** : the _"last_contact_duration attribute"_ highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.

# %%
stat, p, dof, expected =chi2_contingency(pd.crosstab(bank['term_deposit_subscribed'], bank['last_contact_duration']))
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 0.0
# Dependent (reject H0)

# %%
stat, p, dof, expected =chi2_contingency(pd.crosstab(bank['term_deposit_subscribed'], bank['balance']))
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 2.7079291218958127e-97
# Dependent (reject H0)

# %%
stat, p, dof, expected =chi2_contingency(pd.crosstab(bank['term_deposit_subscribed'], bank['job']))
# interpret p-value
alpha = 0.05
print("p value is " + str(p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# p value is 3.337121944935502e-172
# Dependent (reject H0)

# %% [markdown]
# References:
# * Visualizing categorical data : http://seaborn.pydata.org/tutorial/categorical.html
# * Python – Pearson’s Chi-Square Test : https://www.geeksforgeeks.org/python-pearsons-chi-square-test/
